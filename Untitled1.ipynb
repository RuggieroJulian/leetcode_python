# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
students=[5,4,3,6,1]
rows=0
tallest=0
for i,value in enumerate(students):
    if i!=0:
        if value<tallest:
            pass
        else:
            rows+=1
            tallest=value
    else:
        rows+=1
        tallest=value
rows
# Out:
# 2
